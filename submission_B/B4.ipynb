# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
def solution_B4():
    bbc = pd.read_csv('https://github.com/dicodingacademy/assets/raw/main/Simulation/machine_learning/bbc-text.csv')

    # DO NOT CHANGE THIS CODE
    # Make sure you used all of these parameters or you can not pass this test
    vocab_size = 1000
    embedding_dim = 16
    max_length = 120
    trunc_type = 'post'
    padding_type = 'post'
    oov_tok = "<OOV>"
    training_portion = .8

    # YOUR CODE HERE
    # Using "shuffle=False"
    sentences = bbc['text'].tolist()
    labels = bbc['category'].tolist()

    train_size = int(len(sentences) * training_portion)
    training_sentences = sentences[:train_size]
    validation_sentences = sentences[train_size:]
    training_labels = labels[:train_size]
    validation_labels = labels[train_size:]

    # Fit your tokenizer with training data
    tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
    tokenizer.fit_on_texts(training_sentences)
    word_index = tokenizer.word_index

    training_sequences = tokenizer.texts_to_sequences(training_sentences)
    training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

    validation_sequences = tokenizer.texts_to_sequences(validation_sentences)
    validation_padded = pad_sequences(validation_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

    # You can also use Tokenizer to encode your label.
    label_tokenizer = Tokenizer()
    label_tokenizer.fit_on_texts(labels)
    label_word_index = label_tokenizer.word_index

    training_label_sequences = label_tokenizer.texts_to_sequences(training_labels)
    training_label_sequences = np.array(training_label_sequences)
    validation_label_sequences = label_tokenizer.texts_to_sequences(validation_labels)
    validation_label_sequences = np.array(validation_label_sequences)

    model = tf.keras.Sequential([
        # YOUR CODE HERE.
        # YOUR CODE HERE. DO not change the last layer or test may fail
        tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
        tf.keras.layers.GlobalAveragePooling1D(),
        tf.keras.layers.Dense(24, activation='relu'),
        tf.keras.layers.Dense(6, activation='softmax')
    ])

    # Make sure you are using "sparse_categorical_crossentropy" as a loss fuction
    model.compile(loss='sparse_categorical_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                  metrics=['accuracy'])

    model.fit(training_padded, training_label_sequences,
              epochs=50,
              validation_data=(validation_padded, validation_label_sequences),
              verbose=2)

    return model

# %%
# The code below is to save your model as a .h5 file.
# It will be saved automatically in your Submission folder.
if __name__ == '__main__':
    # DO NOT CHANGE THIS CODE
    model = solution_B4()
    model.save("model_B4.h5")
# Out:
# Epoch 1/50
# 56/56 - 1s - loss: 1.7635 - accuracy: 0.2264 - val_loss: 1.7244 - val_accuracy: 0.2382 - 566ms/epoch - 10ms/step
# Epoch 2/50
# 56/56 - 0s - loss: 1.6874 - accuracy: 0.2270 - val_loss: 1.6385 - val_accuracy: 0.2382 - 81ms/epoch - 1ms/step
# Epoch 3/50
# 56/56 - 0s - loss: 1.6032 - accuracy: 0.2551 - val_loss: 1.5553 - val_accuracy: 0.3303 - 76ms/epoch - 1ms/step
# Epoch 4/50
# 56/56 - 0s - loss: 1.5084 - accuracy: 0.4079 - val_loss: 1.4524 - val_accuracy: 0.4270 - 83ms/epoch - 1ms/step
# Epoch 5/50
# 56/56 - 0s - loss: 1.3790 - accuracy: 0.4938 - val_loss: 1.3110 - val_accuracy: 0.5753 - 88ms/epoch - 2ms/step
# Epoch 6/50
# 56/56 - 0s - loss: 1.2166 - accuracy: 0.6202 - val_loss: 1.1515 - val_accuracy: 0.6607 - 80ms/epoch - 1ms/step
# Epoch 7/50
# 56/56 - 0s - loss: 1.0458 - accuracy: 0.7090 - val_loss: 0.9937 - val_accuracy: 0.7708 - 72ms/epoch - 1ms/step
# Epoch 8/50
# 56/56 - 0s - loss: 0.8919 - accuracy: 0.8017 - val_loss: 0.8582 - val_accuracy: 0.8404 - 77ms/epoch - 1ms/step
# Epoch 9/50
# 56/56 - 0s - loss: 0.7578 - accuracy: 0.8579 - val_loss: 0.7435 - val_accuracy: 0.8674 - 79ms/epoch - 1ms/step
# Epoch 10/50
# 56/56 - 0s - loss: 0.6380 - accuracy: 0.9022 - val_loss: 0.6427 - val_accuracy: 0.8831 - 81ms/epoch - 1ms/step
# Epoch 11/50
# 56/56 - 0s - loss: 0.5322 - accuracy: 0.9230 - val_loss: 0.5594 - val_accuracy: 0.9056 - 83ms/epoch - 1ms/step
# Epoch 12/50
# 56/56 - 0s - loss: 0.4448 - accuracy: 0.9331 - val_loss: 0.4864 - val_accuracy: 0.9011 - 75ms/epoch - 1ms/step
# Epoch 13/50
# 56/56 - 0s - loss: 0.3736 - accuracy: 0.9427 - val_loss: 0.4397 - val_accuracy: 0.8989 - 80ms/epoch - 1ms/step
# Epoch 14/50
# 56/56 - 0s - loss: 0.3171 - accuracy: 0.9500 - val_loss: 0.3979 - val_accuracy: 0.9124 - 80ms/epoch - 1ms/step
# Epoch 15/50
# 56/56 - 0s - loss: 0.2723 - accuracy: 0.9579 - val_loss: 0.3646 - val_accuracy: 0.9124 - 80ms/epoch - 1ms/step
# Epoch 16/50
# 56/56 - 0s - loss: 0.2363 - accuracy: 0.9629 - val_loss: 0.3378 - val_accuracy: 0.9213 - 78ms/epoch - 1ms/step
# Epoch 17/50
# 56/56 - 0s - loss: 0.2072 - accuracy: 0.9674 - val_loss: 0.3179 - val_accuracy: 0.9213 - 76ms/epoch - 1ms/step
# Epoch 18/50
# 56/56 - 0s - loss: 0.1827 - accuracy: 0.9697 - val_loss: 0.3014 - val_accuracy: 0.9213 - 78ms/epoch - 1ms/step
# Epoch 19/50
# 56/56 - 0s - loss: 0.1615 - accuracy: 0.9736 - val_loss: 0.2847 - val_accuracy: 0.9236 - 81ms/epoch - 1ms/step
# Epoch 20/50
# 56/56 - 0s - loss: 0.1446 - accuracy: 0.9764 - val_loss: 0.2716 - val_accuracy: 0.9303 - 84ms/epoch - 2ms/step
# Epoch 21/50
# 56/56 - 0s - loss: 0.1296 - accuracy: 0.9798 - val_loss: 0.2673 - val_accuracy: 0.9236 - 81ms/epoch - 1ms/step
# Epoch 22/50
# 56/56 - 0s - loss: 0.1166 - accuracy: 0.9848 - val_loss: 0.2563 - val_accuracy: 0.9281 - 80ms/epoch - 1ms/step
# Epoch 23/50
# 56/56 - 0s - loss: 0.1051 - accuracy: 0.9871 - val_loss: 0.2493 - val_accuracy: 0.9281 - 79ms/epoch - 1ms/step
# Epoch 24/50
# 56/56 - 0s - loss: 0.0952 - accuracy: 0.9871 - val_loss: 0.2420 - val_accuracy: 0.9281 - 84ms/epoch - 2ms/step
# Epoch 25/50
# 56/56 - 0s - loss: 0.0863 - accuracy: 0.9893 - val_loss: 0.2394 - val_accuracy: 0.9258 - 77ms/epoch - 1ms/step
# Epoch 26/50
# 56/56 - 0s - loss: 0.0784 - accuracy: 0.9916 - val_loss: 0.2339 - val_accuracy: 0.9258 - 80ms/epoch - 1ms/step
# Epoch 27/50
# 56/56 - 0s - loss: 0.0711 - accuracy: 0.9933 - val_loss: 0.2284 - val_accuracy: 0.9258 - 75ms/epoch - 1ms/step
# Epoch 28/50
# 56/56 - 0s - loss: 0.0647 - accuracy: 0.9955 - val_loss: 0.2268 - val_accuracy: 0.9258 - 96ms/epoch - 2ms/step
# Epoch 29/50
# 56/56 - 0s - loss: 0.0592 - accuracy: 0.9966 - val_loss: 0.2214 - val_accuracy: 0.9258 - 82ms/epoch - 1ms/step
# Epoch 30/50
# 56/56 - 0s - loss: 0.0540 - accuracy: 0.9972 - val_loss: 0.2225 - val_accuracy: 0.9303 - 83ms/epoch - 1ms/step
# Epoch 31/50
# 56/56 - 0s - loss: 0.0495 - accuracy: 0.9972 - val_loss: 0.2162 - val_accuracy: 0.9258 - 92ms/epoch - 2ms/step
# Epoch 32/50
# 56/56 - 0s - loss: 0.0451 - accuracy: 0.9978 - val_loss: 0.2145 - val_accuracy: 0.9258 - 87ms/epoch - 2ms/step
# Epoch 33/50
# 56/56 - 0s - loss: 0.0416 - accuracy: 0.9978 - val_loss: 0.2151 - val_accuracy: 0.9326 - 88ms/epoch - 2ms/step
# Epoch 34/50
# 56/56 - 0s - loss: 0.0381 - accuracy: 0.9989 - val_loss: 0.2126 - val_accuracy: 0.9326 - 82ms/epoch - 1ms/step
# Epoch 35/50
# 56/56 - 0s - loss: 0.0349 - accuracy: 0.9994 - val_loss: 0.2122 - val_accuracy: 0.9348 - 82ms/epoch - 1ms/step
# Epoch 36/50
# 56/56 - 0s - loss: 0.0320 - accuracy: 0.9994 - val_loss: 0.2111 - val_accuracy: 0.9326 - 85ms/epoch - 2ms/step
# Epoch 37/50
# 56/56 - 0s - loss: 0.0295 - accuracy: 0.9994 - val_loss: 0.2112 - val_accuracy: 0.9348 - 85ms/epoch - 2ms/step
# Epoch 38/50
# 56/56 - 0s - loss: 0.0272 - accuracy: 0.9994 - val_loss: 0.2095 - val_accuracy: 0.9326 - 80ms/epoch - 1ms/step
# Epoch 39/50
# 56/56 - 0s - loss: 0.0251 - accuracy: 0.9994 - val_loss: 0.2068 - val_accuracy: 0.9371 - 81ms/epoch - 1ms/step
# Epoch 40/50
# 56/56 - 0s - loss: 0.0232 - accuracy: 0.9994 - val_loss: 0.2070 - val_accuracy: 0.9326 - 80ms/epoch - 1ms/step
# Epoch 41/50
# 56/56 - 0s - loss: 0.0214 - accuracy: 0.9994 - val_loss: 0.2085 - val_accuracy: 0.9393 - 84ms/epoch - 1ms/step
# Epoch 42/50
# 56/56 - 0s - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.2059 - val_accuracy: 0.9371 - 84ms/epoch - 2ms/step
# Epoch 43/50
# 56/56 - 0s - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.2060 - val_accuracy: 0.9393 - 86ms/epoch - 2ms/step
# Epoch 44/50
# 56/56 - 0s - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.2051 - val_accuracy: 0.9348 - 82ms/epoch - 1ms/step
# Epoch 45/50
# 56/56 - 0s - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.2049 - val_accuracy: 0.9393 - 80ms/epoch - 1ms/step
# Epoch 46/50
# 56/56 - 0s - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.9393 - 84ms/epoch - 2ms/step
# Epoch 47/50
# 56/56 - 0s - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.2059 - val_accuracy: 0.9393 - 91ms/epoch - 2ms/step
# Epoch 48/50
# 56/56 - 0s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.2054 - val_accuracy: 0.9393 - 76ms/epoch - 1ms/step
# Epoch 49/50
# 56/56 - 0s - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.2056 - val_accuracy: 0.9393 - 79ms/epoch - 1ms/step
# Epoch 50/50
# 56/56 - 0s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.2053 - val_accuracy: 0.9393 - 82ms/epoch - 1ms/step
# c:\Users\ilham\miniconda3\envs\vision1\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
